# %% [markdown]
# # **Mobile Legend Review Analysis Sentiment - by Edrin Firdaus**

# %% [markdown]
# ## **Preparation**

# %% [markdown]
# Disini saya akan melakukan scrapping dari Google Play Store dengan bahasa pemrograman Python.

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Import Library**

# %% [markdown]
# Saya akan melakukan import library dari google play scraper dengan berupa data pandas

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %% [markdown]
# ## **Scrapping**

# %% [markdown]
# Aplikasi yang saya pilih yaitu Sapa warga Jabar Super Apps dengan mengambil semua review yang ada.

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.mobile.legends',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=25000,
    filter_score_with=None
)

# %% [markdown]
# Saya menggunakan review aplikasi 'Mobile legends Bang Bang' berdasarkan review terbaru dan mengambil 25.000 review pengguna.

# %% [markdown]
# ## **Review Data**

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId         userName  \
# 0  fafd3670-46c4-4c80-a59a-6fa79658360b  Pengguna Google
# 1  a174445c-dafb-4811-ad9b-dc931fc9430f  Pengguna Google
# 2  aca703d2-b062-4313-8628-835f9d78ae87  Pengguna Google
# 3  ca19e29a-6824-491c-97cb-27d32fe8ec07  Pengguna Google
# 4  73772936-1f26-4b17-af3e-4c201ece51c6  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0       game ini lengkap bangetttt kalian harus coba      5              0
# 1                                  game nya bagus 👍👍      1              0
# ...

# %%
len(df_busu.index)
# Out:
# 25000

# %% [markdown]
# Save file ke CSV

# %%
df_busu.to_csv("mobile_legends_review.csv", index = False)
